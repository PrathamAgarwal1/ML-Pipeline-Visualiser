# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# This notebook contains the Exploratory Data Analysis (EDA) functions used in the pipeline. It is imported directly by `app.py`.

# %%
import numpy as np
import pandas as pd
import io
import base64
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### 1. Descriptive Statistics

# %%
def generate_descriptive_stats(df):
    return df.describe().to_html(classes='table table-sm table-bordered')

# %% [markdown]
# ### 2. Correlation Heatmap

# %%
def generate_correlation_heatmap(df):
    corr = df.corr(numeric_only=True)
    plt.figure(figsize=(10, 8))
    sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f")
    img = io.BytesIO()
    plt.savefig(img, format='png', bbox_inches='tight')
    img.seek(0)
    heatmap_url = base64.b64encode(img.getvalue()).decode()
    plt.close()
    return heatmap_url

# %% [markdown]
# ### 3. Dynamic Plottings

# %%
def generate_plot(df, plot_type, col1, col2=None):
    plt.figure(figsize=(8, 5))
    if plot_type == 'histogram':
        sns.histplot(df[col1], kde=True)
        plt.title(f'Histogram of {col1}')
    elif plot_type == 'boxplot':
        sns.boxplot(y=df[col1])
        plt.title(f'Boxplot of {col1}')
    elif plot_type == 'scatter' and col2:
        sns.scatterplot(x=df[col1], y=df[col2])
        plt.title(f'Scatter Plot: {col1} vs {col2}')
        
    img = io.BytesIO()
    plt.savefig(img, format='png', bbox_inches='tight')
    img.seek(0)
    plot_url = base64.b64encode(img.getvalue()).decode()
    plt.close()
    return f'data:image/png;base64,{plot_url}'
